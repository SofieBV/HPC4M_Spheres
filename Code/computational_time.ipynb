# %%
## Plot results 
import numpy as np
import matplotlib.pyplot as plt

n=[10,20,40,60,80,100,200]
serial = [0.006,0.041,0.2,0.54,1.34,2.43,22.85]
parallel = [0.02,0.11,0.14,0.476,0.89,1.559,13.36]

# plt.loglog(n,serial,label="serial")
# plt.loglog(n,parallel,label="parallel")
# plt.legend()
# plt.title("Computional time")
# plt.xlabel("number of particles")
# plt.ylabel("time")

plt.plot(n,serial,label="serial",color="blue")
plt.plot(n,parallel,label="parallel",color="red")
plt.plot(n,serial,"x",color="blue")
plt.plot(n,parallel,"x",color="red")
plt.legend()
# plt.title("Improvement serial vs parallel",fontsize=20)
plt.xlabel("number of particles",fontsize=15)
plt.ylabel("time",fontsize=15)
# Out:
# Text(0, 0.5, 'time')
