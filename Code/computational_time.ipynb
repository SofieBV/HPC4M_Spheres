# %%
## Plot results 
import numpy as np
import matplotlib.pyplot as plt

n=[10,20,40,60,80,100]
serial = [0.006,0.041,0.2,0.54,1.34,2.43]
parallel = [0.02,0.11,0.14,0.476,0.89,1.559]

plt.plot(n,serial,label="serial")
plt.plot(n,parallel,label="parallel")
plt.legend()
plt.title("Computional time")
plt.xlabel("number of particles")
plt.ylabel("time")
# Out:
# Text(0, 0.5, 'time')
